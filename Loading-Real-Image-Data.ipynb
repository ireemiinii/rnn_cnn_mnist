# %% [markdown]
# # Loading Real Image Data
# So far we've only worked with toy datasets (MNIST, CIFAR-10) conveniently packaged by torchvision, where every image has the same size and shape. Now let's learn the real deal, and work from a varied collection of .jpg files.
#
# For this section we'll be working with a version of the Cats vs. Dogs dataset inspired by a classic <a href='https://www.kaggle.com/c/dogs-vs-cats'>Kaggle competition</a>.<br>
# A quick note - do <strong>not</strong> download the dataset from Kaggle! Ours is a cleaned version of the data without any 0by0 files, etc.<br>The images are similar to ones available from the <a href='http://www.image-net.org/'>ImageNet</a> database.
#
# link: https://drive.google.com/drive/folders/1v6Reg5Jwrvx3KI8gbE0tq7aRkncMIQne?usp=sharing
#
# We have organized the files into train and test folders, and further divided the images into CAT and DOG subfolders. In this way the file path contains the label.

# %% [markdown]
# ### Image files directory tree
# <pre>.
# └── Data
#     └── CATS_DOGS
#         ├── test
#         │   ├── CAT
#         │   │   ├── 9374.jpg
#         │   │   ├── 9375.jpg
#         │   │   └── ... (3,126 files)
#         │   └── DOG
#         │       ├── 9374.jpg
#         │       ├── 9375.jpg
#         │       └── ... (3,125 files)
#         │
#         └── train
#             ├── CAT
#             │   ├── 0.jpg
#             │   ├── 1.jpg
#             │   └── ... (9,371 files)
#             └── DOG
#                 ├── 0.jpg
#                 ├── 1.jpg
#                 └── ... (9,372 files)</pre>

# %% [markdown]
# ## Perform standard imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Examine the data
# We'll us Python's built-in <a href='https://docs.python.org/3/library/os.html'>os module</a> to walk the directories collecting file names. We'll then use <a href='https://python-pillow.org/'>Pillow</a>, an extension to the Python Imaging Library (PIL), to open image files and extract image sizes. A pandas DataFrame will provide summary statistics on our data like max/min width & height from which we can choose our model parameters.

# %%
import os
from PIL import Image
from IPython.display import display

# Filter harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# TEST YOUR VERSION OF PILLOW
# Run this cell. If you see a picture of a cat you're all set!
with Image.open('CATS_DOGS/test/CAT/10100.jpg') as im:
    display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=223x220 at 0x7F6C0829D580>

# %% [markdown]
# ### Create a list of image filenames

# %%
path = 'CATS_DOGS/'
img_names = []

for folder, subfolders, filenames in os.walk(path):
    for img in filenames:
        img_names.append(folder+'/'+img)
        
print('Images: ',len(img_names))
# Out:
# Images:  24994

# %%
img_names
# Out:
# ['CATS_DOGS/train/CAT/3091.jpg',
#  'CATS_DOGS/train/CAT/1628.jpg',
#  'CATS_DOGS/train/CAT/9136.jpg',
#  'CATS_DOGS/train/CAT/7859.jpg',
#  'CATS_DOGS/train/CAT/6606.jpg',
#  'CATS_DOGS/train/CAT/5102.jpg',
#  'CATS_DOGS/train/CAT/9176.jpg',
#  'CATS_DOGS/train/CAT/7168.jpg',
#  'CATS_DOGS/train/CAT/6111.jpg',
#  'CATS_DOGS/train/CAT/1906.jpg',
#  'CATS_DOGS/train/CAT/7882.jpg',
#  'CATS_DOGS/train/CAT/9198.jpg',
#  'CATS_DOGS/train/CAT/5784.jpg',
#  'CATS_DOGS/train/CAT/2413.jpg',
#  'CATS_DOGS/train/CAT/1363.jpg',
#  'CATS_DOGS/train/CAT/2504.jpg',
#  'CATS_DOGS/train/CAT/7942.jpg',
#  'CATS_DOGS/train/CAT/6895.jpg',
#  'CATS_DOGS/train/CAT/3302.jpg',
#  'CATS_DOGS/train/CAT/8749.jpg',
#  'CATS_DOGS/train/CAT/5482.jpg',
#  'CATS_DOGS/train/CAT/8350.jpg',
#  'CATS_DOGS/train/CAT/4804.jpg',
#  'CATS_DOGS/train/CAT/4203.jpg',
#  'CATS_DOGS/train/CAT/4719.jpg',
#  'CATS_DOGS/train/CAT/9050.jpg',
#  'CATS_DOGS/train/CAT/1174.jpg',
#  'CATS_DOGS/train/CAT/972.jpg',
#  'CATS_DOGS/train/CAT/4680.jpg',
#  'CATS_DOGS/train/CAT/3980.jpg',
#  'CATS_DOGS/train/CAT/8584.jpg',
#  'CATS_DOGS/train/CAT/2227.jpg',
#  'CATS_DOGS/train/CAT/3295.jpg',
#  'CATS_DOGS/train/CAT/6437.jpg',
#  'CATS_DOGS/train/CAT/7541.jpg',
#  'CATS_DOGS/train/CAT/1940.jpg',
#  'CATS_DOGS/train/CAT/2562.jpg',
#  'CATS_DOGS/train/CAT/4848.jpg',
#  'CATS_DOGS/train/CAT/3025.jpg',
#  'CATS_DOGS/train/CAT/3475.jpg',
#  'CATS_DOGS/train/CAT/9175.jpg',
#  'CATS_DOGS/train/CAT/5236.jpg',
#  'CATS_DOGS/train/CAT/2011.jpg',
#  'CATS_DOGS/train/CAT/2216.jpg',
#  'CATS_DOGS/train/CAT/1063.jpg',
#  'CATS_DOGS/train/CAT/3483.jpg',
#  'CATS_DOGS/train/CAT/2333.jpg',
#  'CATS_DOGS/train/CAT/7578.jpg',
#  'CATS_DOGS/train/CAT/7291.jpg',
#  'CATS_DOGS/train/CAT/309.jpg',
#  'CATS_DOGS/train/CAT/8686.jpg',
#  'CATS_DOGS/train/CAT/7816.jpg',
#  'CATS_DOGS/train/CAT/4190.jpg',
#  'CATS_DOGS/train/CAT/4164.jpg',
#  'CATS_DOGS/train/CAT/6667.jpg',
#  'CATS_DOGS/train/CAT/669.jpg',
#  'CATS_DOGS/train/CAT/4559.jpg',
#  'CATS_DOGS/train/CAT/2572.jpg',
#  'CATS_DOGS/train/CAT/6245.jpg',
#  'CATS_DOGS/train/CAT/6846.jpg',
#  'CATS_DOGS/train/CAT/8238.jpg',
#  'CATS_DOGS/train/CAT/1797.jpg',
#  'CATS_DOGS/train/CAT/1178.jpg',
#  'CATS_DOGS/train/CAT/2198.jpg',
#  'CATS_DOGS/train/CAT/976.jpg',
#  'CATS_DOGS/train/CAT/2459.jpg',
#  'CATS_DOGS/train/CAT/3501.jpg',
#  'CATS_DOGS/train/CAT/2926.jpg',
#  'CATS_DOGS/train/CAT/8970.jpg',
#  'CATS_DOGS/train/CAT/2665.jpg',
#  'CATS_DOGS/train/CAT/1071.jpg',
#  'CATS_DOGS/train/CAT/3076.jpg',
#  'CATS_DOGS/train/CAT/4942.jpg',
#  'CATS_DOGS/train/CAT/3770.jpg',
#  'CATS_DOGS/train/CAT/7888.jpg',
#  'CATS_DOGS/train/CAT/3751.jpg',
#  'CATS_DOGS/train/CAT/522.jpg',
#  'CATS_DOGS/train/CAT/5083.jpg',
#  'CATS_DOGS/train/CAT/8910.jpg',
#  'CATS_DOGS/train/CAT/6618.jpg',
#  'CATS_DOGS/train/CAT/2984.jpg',
#  'CATS_DOGS/train/CAT/6878.jpg',
#  'CATS_DOGS/train/CAT/1080.jpg',
#  'CATS_DOGS/train/CAT/6925.jpg',
#  'CATS_DOGS/train/CAT/1900.jpg',
#  'CATS_DOGS/train/CAT/5571.jpg',
#  'CATS_DOGS/train/CAT/4604.jpg',
#  'CATS_DOGS/train/CAT/3630.jpg',
#  'CATS_DOGS/train/CAT/2541.jpg',
#  'CATS_DOGS/train/CAT/8758.jpg',
#  'CATS_DOGS/train/CAT/7057.jpg',
#  'CATS_DOGS/train/CAT/5394.jpg',
#  'CATS_DOGS/train/CAT/8207.jpg',
#  'CATS_DOGS/train/CAT/6225.jpg',
#  'CATS_DOGS/train/CAT/3767.jpg',
#  'CATS_DOGS/train/CAT/2285.jpg',
#  'CATS_DOGS/train/CAT/859.jpg',
#  'CATS_DOGS/train/CAT/4541.jpg',
#  'CATS_DOGS/train/CAT/7453.jpg',
#  'CATS_DOGS/train/CAT/2170.jpg',
#  'CATS_DOGS/train/CAT/3969.jpg',
#  'CATS_DOGS/train/CAT/2144.jpg',
#  'CATS_DOGS/train/CAT/2903.jpg',
#  'CATS_DOGS/train/CAT/6844.jpg',
#  'CATS_DOGS/train/CAT/2081.jpg',
#  'CATS_DOGS/train/CAT/2322.jpg',
#  'CATS_DOGS/train/CAT/1711.jpg',
#  'CATS_DOGS/train/CAT/8961.jpg',
#  'CATS_DOGS/train/CAT/4828.jpg',
#  'CATS_DOGS/train/CAT/6921.jpg',
#  'CATS_DOGS/train/CAT/131.jpg',
#  'CATS_DOGS/train/CAT/4924.jpg',
#  'CATS_DOGS/train/CAT/3629.jpg',
#  'CATS_DOGS/train/CAT/5994.jpg',
#  'CATS_DOGS/train/CAT/4235.jpg',
#  'CATS_DOGS/train/CAT/6951.jpg',
#  'CATS_DOGS/train/CAT/6614.jpg',
#  'CATS_DOGS/train/CAT/9141.jpg',
#  'CATS_DOGS/train/CAT/280.jpg',
#  'CATS_DOGS/train/CAT/720.jpg',
#  'CATS_DOGS/train/CAT/8092.jpg',
#  'CATS_DOGS/train/CAT/2842.jpg',
#  'CATS_DOGS/train/CAT/2282.jpg',
#  'CATS_DOGS/train/CAT/3680.jpg',
#  'CATS_DOGS/train/CAT/4633.jpg',
#  'CATS_DOGS/train/CAT/6730.jpg',
#  'CATS_DOGS/train/CAT/3070.jpg',
#  'CATS_DOGS/train/CAT/8022.jpg',
#  'CATS_DOGS/train/CAT/549.jpg',
#  'CATS_DOGS/train/CAT/5997.jpg',
#  'CATS_DOGS/train/CAT/4472.jpg',
#  'CATS_DOGS/train/CAT/4787.jpg',
#  'CATS_DOGS/train/CAT/6149.jpg',
#  'CATS_DOGS/train/CAT/295.jpg',
#  'CATS_DOGS/train/CAT/3706.jpg',
#  'CATS_DOGS/train/CAT/1314.jpg',
#  'CATS_DOGS/train/CAT/5706.jpg',
#  'CATS_DOGS/train/CAT/2753.jpg',
#  'CATS_DOGS/train/CAT/9152.jpg',
#  'CATS_DOGS/train/CAT/9252.jpg',
#  'CATS_DOGS/train/CAT/7950.jpg',
#  'CATS_DOGS/train/CAT/8179.jpg',
#  'CATS_DOGS/train/CAT/4239.jpg',
#  'CATS_DOGS/train/CAT/110.jpg',
#  'CATS_DOGS/train/CAT/5086.jpg',
#  'CATS_DOGS/train/CAT/1744.jpg',
#  'CATS_DOGS/train/CAT/6589.jpg',
#  'CATS_DOGS/train/CAT/7535.jpg',
#  'CATS_DOGS/train/CAT/8893.jpg',
#  'CATS_DOGS/train/CAT/468.jpg',
#  'CATS_DOGS/train/CAT/7662.jpg',
#  'CATS_DOGS/train/CAT/5545.jpg',
#  'CATS_DOGS/train/CAT/336.jpg',
#  'CATS_DOGS/train/CAT/545.jpg',
#  'CATS_DOGS/train/CAT/6833.jpg',
#  'CATS_DOGS/train/CAT/2294.jpg',
#  'CATS_DOGS/train/CAT/685.jpg',
#  'CATS_DOGS/train/CAT/8864.jpg',
#  'CATS_DOGS/train/CAT/1067.jpg',
#  'CATS_DOGS/train/CAT/8757.jpg',
#  'CATS_DOGS/train/CAT/5512.jpg',
#  'CATS_DOGS/train/CAT/5080.jpg',
#  'CATS_DOGS/train/CAT/2727.jpg',
#  'CATS_DOGS/train/CAT/6950.jpg',
#  'CATS_DOGS/train/CAT/8082.jpg',
#  'CATS_DOGS/train/CAT/1680.jpg',
#  'CATS_DOGS/train/CAT/6048.jpg',
#  'CATS_DOGS/train/CAT/2867.jpg',
#  'CATS_DOGS/train/CAT/6978.jpg',
#  'CATS_DOGS/train/CAT/1066.jpg',
#  'CATS_DOGS/train/CAT/6984.jpg',
#  'CATS_DOGS/train/CAT/2930.jpg',
#  'CATS_DOGS/train/CAT/1533.jpg',
#  'CATS_DOGS/train/CAT/1623.jpg',
#  'CATS_DOGS/train/CAT/6509.jpg',
#  'CATS_DOGS/train/CAT/2540.jpg',
#  'CATS_DOGS/train/CAT/2035.jpg',
#  'CATS_DOGS/train/CAT/7483.jpg',
#  'CATS_DOGS/train/CAT/8210.jpg',
#  'CATS_DOGS/train/CAT/1560.jpg',
#  'CATS_DOGS/train/CAT/1664.jpg',
#  'CATS_DOGS/train/CAT/435.jpg',
#  'CATS_DOGS/train/CAT/7687.jpg',
#  'CATS_DOGS/train/CAT/7333.jpg',
#  'CATS_DOGS/train/CAT/4562.jpg',
#  'CATS_DOGS/train/CAT/8812.jpg',
#  'CATS_DOGS/train/CAT/4724.jpg',
#  'CATS_DOGS/train/CAT/4739.jpg',
#  'CATS_DOGS/train/CAT/345.jpg',
#  'CATS_DOGS/train/CAT/4777.jpg',
#  'CATS_DOGS/train/CAT/6342.jpg',
#  'CATS_DOGS/train/CAT/2794.jpg',
#  'CATS_DOGS/train/CAT/1574.jpg',
#  'CATS_DOGS/train/CAT/1226.jpg',
#  'CATS_DOGS/train/CAT/845.jpg',
#  'CATS_DOGS/train/CAT/580.jpg',
#  'CATS_DOGS/train/CAT/3124.jpg',
#  'CATS_DOGS/train/CAT/7943.jpg',
#  'CATS_DOGS/train/CAT/1009.jpg',
#  'CATS_DOGS/train/CAT/1123.jpg',
#  'CATS_DOGS/train/CAT/1592.jpg',
#  'CATS_DOGS/train/CAT/3129.jpg',
#  'CATS_DOGS/train/CAT/5104.jpg',
#  'CATS_DOGS/train/CAT/788.jpg',
#  'CATS_DOGS/train/CAT/8167.jpg',
#  'CATS_DOGS/train/CAT/7665.jpg',
#  'CATS_DOGS/train/CAT/4702.jpg',
#  'CATS_DOGS/train/CAT/9.jpg',
#  'CATS_DOGS/train/CAT/521.jpg',
#  'CATS_DOGS/train/CAT/3154.jpg',
#  'CATS_DOGS/train/CAT/454.jpg',
#  'CATS_DOGS/train/CAT/3107.jpg',
#  'CATS_DOGS/train/CAT/5726.jpg',
#  'CATS_DOGS/train/CAT/4139.jpg',
#  'CATS_DOGS/train/CAT/8264.jpg',
#  'CATS_DOGS/train/CAT/357.jpg',
#  'CATS_DOGS/train/CAT/8866.jpg',
#  'CATS_DOGS/train/CAT/683.jpg',
#  'CATS_DOGS/train/CAT/4930.jpg',
#  'CATS_DOGS/train/CAT/854.jpg',
#  'CATS_DOGS/train/CAT/6999.jpg',
#  'CATS_DOGS/train/CAT/331.jpg',
#  'CATS_DOGS/train/CAT/7021.jpg',
#  'CATS_DOGS/train/CAT/5398.jpg',
#  'CATS_DOGS/train/CAT/6556.jpg',
#  'CATS_DOGS/train/CAT/116.jpg',
#  'CATS_DOGS/train/CAT/121.jpg',
#  'CATS_DOGS/train/CAT/8282.jpg',
#  'CATS_DOGS/train/CAT/2158.jpg',
#  'CATS_DOGS/train/CAT/5058.jpg',
#  'CATS_DOGS/train/CAT/524.jpg',
#  'CATS_DOGS/train/CAT/4304.jpg',
#  'CATS_DOGS/train/CAT/2367.jpg',
#  'CATS_DOGS/train/CAT/2428.jpg',
#  'CATS_DOGS/train/CAT/8333.jpg',
#  'CATS_DOGS/train/CAT/4092.jpg',
#  'CATS_DOGS/train/CAT/5356.jpg',
#  'CATS_DOGS/train/CAT/5090.jpg',
#  'CATS_DOGS/train/CAT/792.jpg',
#  'CATS_DOGS/train/CAT/578.jpg',
#  'CATS_DOGS/train/CAT/1871.jpg',
#  'CATS_DOGS/train/CAT/3793.jpg',
#  'CATS_DOGS/train/CAT/324.jpg',
#  'CATS_DOGS/train/CAT/5155.jpg',
#  'CATS_DOGS/train/CAT/7506.jpg',
#  'CATS_DOGS/train/CAT/8035.jpg',
#  'CATS_DOGS/train/CAT/1489.jpg',
#  'CATS_DOGS/train/CAT/7217.jpg',
#  'CATS_DOGS/train/CAT/2380.jpg',
#  'CATS_DOGS/train/CAT/7321.jpg',
#  'CATS_DOGS/train/CAT/698.jpg',
#  'CATS_DOGS/train/CAT/6165.jpg',
#  'CATS_DOGS/train/CAT/3387.jpg',
#  'CATS_DOGS/train/CAT/6775.jpg',
#  'CATS_DOGS/train/CAT/9355.jpg',
#  'CATS_DOGS/train/CAT/9106.jpg',
#  'CATS_DOGS/train/CAT/606.jpg',
#  'CATS_DOGS/train/CAT/442.jpg',
#  'CATS_DOGS/train/CAT/6367.jpg',
#  'CATS_DOGS/train/CAT/728.jpg',
#  'CATS_DOGS/train/CAT/8612.jpg',
#  'CATS_DOGS/train/CAT/7279.jpg',
#  'CATS_DOGS/train/CAT/7086.jpg',
#  'CATS_DOGS/train/CAT/5844.jpg',
#  'CATS_DOGS/train/CAT/1434.jpg',
#  'CATS_DOGS/train/CAT/3687.jpg',
#  'CATS_DOGS/train/CAT/761.jpg',
#  'CATS_DOGS/train/CAT/718.jpg',
#  'CATS_DOGS/train/CAT/100.jpg',
#  'CATS_DOGS/train/CAT/5504.jpg',
#  'CATS_DOGS/train/CAT/4889.jpg',
#  'CATS_DOGS/train/CAT/1865.jpg',
#  'CATS_DOGS/train/CAT/2678.jpg',
#  'CATS_DOGS/train/CAT/9168.jpg',
#  'CATS_DOGS/train/CAT/1933.jpg',
#  'CATS_DOGS/train/CAT/1500.jpg',
#  'CATS_DOGS/train/CAT/5869.jpg',
#  'CATS_DOGS/train/CAT/4937.jpg',
#  'CATS_DOGS/train/CAT/3390.jpg',
#  'CATS_DOGS/train/CAT/7781.jpg',
#  'CATS_DOGS/train/CAT/2049.jpg',
#  'CATS_DOGS/train/CAT/2639.jpg',
#  'CATS_DOGS/train/CAT/9182.jpg',
#  'CATS_DOGS/train/CAT/3068.jpg',
#  'CATS_DOGS/train/CAT/5727.jpg',
#  'CATS_DOGS/train/CAT/9020.jpg',
#  'CATS_DOGS/train/CAT/287.jpg',
#  'CATS_DOGS/train/CAT/5873.jpg',
#  'CATS_DOGS/train/CAT/491.jpg',
#  'CATS_DOGS/train/CAT/2179.jpg',
#  'CATS_DOGS/train/CAT/2415.jpg',
#  'CATS_DOGS/train/CAT/3826.jpg',
#  'CATS_DOGS/train/CAT/541.jpg',
#  'CATS_DOGS/train/CAT/2945.jpg',
#  'CATS_DOGS/train/CAT/7796.jpg',
#  'CATS_DOGS/train/CAT/5152.jpg',
#  'CATS_DOGS/train/CAT/6451.jpg',
#  'CATS_DOGS/train/CAT/1855.jpg',
#  'CATS_DOGS/train/CAT/2266.jpg',
#  'CATS_DOGS/train/CAT/8377.jpg',
#  'CATS_DOGS/train/CAT/5894.jpg',
#  'CATS_DOGS/train/CAT/8929.jpg',
#  'CATS_DOGS/train/CAT/8407.jpg',
#  'CATS_DOGS/train/CAT/5842.jpg',
#  'CATS_DOGS/train/CAT/9097.jpg',
#  'CATS_DOGS/train/CAT/7209.jpg',
#  'CATS_DOGS/train/CAT/1333.jpg',
#  'CATS_DOGS/train/CAT/8425.jpg',
#  'CATS_DOGS/train/CAT/6414.jpg',
#  'CATS_DOGS/train/CAT/7000.jpg',
#  'CATS_DOGS/train/CAT/925.jpg',
#  'CATS_DOGS/train/CAT/4008.jpg',
#  'CATS_DOGS/train/CAT/6429.jpg',
#  'CATS_DOGS/train/CAT/4337.jpg',
#  'CATS_DOGS/train/CAT/6204.jpg',
#  'CATS_DOGS/train/CAT/8416.jpg',
#  'CATS_DOGS/train/CAT/5855.jpg',
#  'CATS_DOGS/train/CAT/2846.jpg',
#  'CATS_DOGS/train/CAT/7252.jpg',
#  'CATS_DOGS/train/CAT/6310.jpg',
#  'CATS_DOGS/train/CAT/8889.jpg',
#  'CATS_DOGS/train/CAT/5795.jpg',
#  'CATS_DOGS/train/CAT/6800.jpg',
#  'CATS_DOGS/train/CAT/7245.jpg',
#  'CATS_DOGS/train/CAT/200.jpg',
#  'CATS_DOGS/train/CAT/7134.jpg',
#  'CATS_DOGS/train/CAT/1766.jpg',
#  'CATS_DOGS/train/CAT/1848.jpg',
#  'CATS_DOGS/train/CAT/3314.jpg',
#  'CATS_DOGS/train/CAT/5742.jpg',
#  'CATS_DOGS/train/CAT/5513.jpg',
#  'CATS_DOGS/train/CAT/8507.jpg',
#  'CATS_DOGS/train/CAT/5922.jpg',
#  'CATS_DOGS/train/CAT/3042.jpg',
#  'CATS_DOGS/train/CAT/5910.jpg',
#  'CATS_DOGS/train/CAT/1681.jpg',
#  'CATS_DOGS/train/CAT/5230.jpg',
#  'CATS_DOGS/train/CAT/7462.jpg',
#  'CATS_DOGS/train/CAT/6725.jpg',
#  'CATS_DOGS/train/CAT/8115.jpg',
#  'CATS_DOGS/train/CAT/5170.jpg',
#  'CATS_DOGS/train/CAT/4671.jpg',
#  'CATS_DOGS/train/CAT/4752.jpg',
#  'CATS_DOGS/train/CAT/23.jpg',
#  'CATS_DOGS/train/CAT/4812.jpg',
#  'CATS_DOGS/train/CAT/8364.jpg',
#  'CATS_DOGS/train/CAT/911.jpg',
#  'CATS_DOGS/train/CAT/1789.jpg',
#  'CATS_DOGS/train/CAT/4824.jpg',
#  'CATS_DOGS/train/CAT/6044.jpg',
#  'CATS_DOGS/train/CAT/4990.jpg',
#  'CATS_DOGS/train/CAT/7832.jpg',
#  'CATS_DOGS/train/CAT/4353.jpg',
#  'CATS_DOGS/train/CAT/6594.jpg',
#  'CATS_DOGS/train/CAT/7244.jpg',
#  'CATS_DOGS/train/CAT/1388.jpg',
#  'CATS_DOGS/train/CAT/2743.jpg',
#  'CATS_DOGS/train/CAT/4096.jpg',
#  'CATS_DOGS/train/CAT/804.jpg',
#  'CATS_DOGS/train/CAT/7720.jpg',
#  'CATS_DOGS/train/CAT/3485.jpg',
#  'CATS_DOGS/train/CAT/386.jpg',
#  'CATS_DOGS/train/CAT/1173.jpg',
#  'CATS_DOGS/train/CAT/880.jpg',
#  'CATS_DOGS/train/CAT/6338.jpg',
#  'CATS_DOGS/train/CAT/6545.jpg',
#  'CATS_DOGS/train/CAT/9133.jpg',
#  'CATS_DOGS/train/CAT/2126.jpg',
#  'CATS_DOGS/train/CAT/8067.jpg',
#  'CATS_DOGS/train/CAT/3223.jpg',
#  'CATS_DOGS/train/CAT/4476.jpg',
#  'CATS_DOGS/train/CAT/7956.jpg',
#  'CATS_DOGS/train/CAT/8494.jpg',
#  'CATS_DOGS/train/CAT/1331.jpg',
#  'CATS_DOGS/train/CAT/5288.jpg',
#  'CATS_DOGS/train/CAT/6306.jpg',
#  'CATS_DOGS/train/CAT/366.jpg',
#  'CATS_DOGS/train/CAT/7359.jpg',
#  'CATS_DOGS/train/CAT/8250.jpg',
#  'CATS_DOGS/train/CAT/3658.jpg',
#  'CATS_DOGS/train/CAT/6127.jpg',
#  'CATS_DOGS/train/CAT/8263.jpg',
#  'CATS_DOGS/train/CAT/5785.jpg',
#  'CATS_DOGS/train/CAT/7494.jpg',
#  'CATS_DOGS/train/CAT/605.jpg',
#  'CATS_DOGS/train/CAT/4735.jpg',
#  'CATS_DOGS/train/CAT/2961.jpg',
#  'CATS_DOGS/train/CAT/6396.jpg',
#  'CATS_DOGS/train/CAT/6007.jpg',
#  'CATS_DOGS/train/CAT/544.jpg',
#  'CATS_DOGS/train/CAT/8525.jpg',
#  'CATS_DOGS/train/CAT/9149.jpg',
#  'CATS_DOGS/train/CAT/716.jpg',
#  'CATS_DOGS/train/CAT/4383.jpg',
#  'CATS_DOGS/train/CAT/1611.jpg',
#  'CATS_DOGS/train/CAT/5.jpg',
#  'CATS_DOGS/train/CAT/6898.jpg',
#  'CATS_DOGS/train/CAT/7430.jpg',
#  'CATS_DOGS/train/CAT/3846.jpg',
#  'CATS_DOGS/train/CAT/5645.jpg',
#  'CATS_DOGS/train/CAT/1801.jpg',
#  'CATS_DOGS/train/CAT/1522.jpg',
#  'CATS_DOGS/train/CAT/1190.jpg',
#  'CATS_DOGS/train/CAT/3560.jpg',
#  'CATS_DOGS/train/CAT/22.jpg',
#  'CATS_DOGS/train/CAT/1348.jpg',
#  'CATS_DOGS/train/CAT/9349.jpg',
#  'CATS_DOGS/train/CAT/4519.jpg',
#  'CATS_DOGS/train/CAT/2920.jpg',
#  'CATS_DOGS/train/CAT/3408.jpg',
#  'CATS_DOGS/train/CAT/1099.jpg',
#  'CATS_DOGS/train/CAT/6028.jpg',
#  'CATS_DOGS/train/CAT/4385.jpg',
#  'CATS_DOGS/train/CAT/1795.jpg',
#  'CATS_DOGS/train/CAT/8883.jpg',
#  'CATS_DOGS/train/CAT/5016.jpg',
#  'CATS_DOGS/train/CAT/8966.jpg',
#  'CATS_DOGS/train/CAT/1203.jpg',
#  'CATS_DOGS/train/CAT/2474.jpg',
#  'CATS_DOGS/train/CAT/3743.jpg',
#  'CATS_DOGS/train/CAT/3686.jpg',
#  'CATS_DOGS/train/CAT/7144.jpg',
#  'CATS_DOGS/train/CAT/399.jpg',
#  'CATS_DOGS/train/CAT/4807.jpg',
#  'CATS_DOGS/train/CAT/5001.jpg',
#  'CATS_DOGS/train/CAT/1209.jpg',
#  'CATS_DOGS/train/CAT/7519.jpg',
#  'CATS_DOGS/train/CAT/4309.jpg',
#  'CATS_DOGS/train/CAT/8428.jpg',
#  'CATS_DOGS/train/CAT/1961.jpg',
#  'CATS_DOGS/train/CAT/3945.jpg',
#  'CATS_DOGS/train/CAT/3878.jpg',
#  'CATS_DOGS/train/CAT/5259.jpg',
#  'CATS_DOGS/train/CAT/80.jpg',
#  'CATS_DOGS/train/CAT/9254.jpg',
#  'CATS_DOGS/train/CAT/1879.jpg',
#  'CATS_DOGS/train/CAT/8062.jpg',
#  'CATS_DOGS/train/CAT/3305.jpg',
#  'CATS_DOGS/train/CAT/7983.jpg',
#  'CATS_DOGS/train/CAT/7189.jpg',
#  'CATS_DOGS/train/CAT/4568.jpg',
#  'CATS_DOGS/train/CAT/2847.jpg',
#  'CATS_DOGS/train/CAT/8462.jpg',
#  'CATS_DOGS/train/CAT/780.jpg',
#  'CATS_DOGS/train/CAT/4050.jpg',
#  'CATS_DOGS/train/CAT/7354.jpg',
#  'CATS_DOGS/train/CAT/7282.jpg',
#  'CATS_DOGS/train/CAT/1665.jpg',
#  'CATS_DOGS/train/CAT/4941.jpg',
#  'CATS_DOGS/train/CAT/920.jpg',
#  'CATS_DOGS/train/CAT/9193.jpg',
#  'CATS_DOGS/train/CAT/3902.jpg',
#  'CATS_DOGS/train/CAT/5148.jpg',
#  'CATS_DOGS/train/CAT/3053.jpg',
#  'CATS_DOGS/train/CAT/1490.jpg',
#  'CATS_DOGS/train/CAT/306.jpg',
#  'CATS_DOGS/train/CAT/2425.jpg',
#  'CATS_DOGS/train/CAT/2954.jpg',
#  'CATS_DOGS/train/CAT/5606.jpg',
#  'CATS_DOGS/train/CAT/1615.jpg',
#  'CATS_DOGS/train/CAT/413.jpg',
#  'CATS_DOGS/train/CAT/8475.jpg',
#  'CATS_DOGS/train/CAT/7327.jpg',
#  'CATS_DOGS/train/CAT/2182.jpg',
#  'CATS_DOGS/train/CAT/5249.jpg',
#  'CATS_DOGS/train/CAT/7915.jpg',
#  'CATS_DOGS/train/CAT/5969.jpg',
#  'CATS_DOGS/train/CAT/8892.jpg',
#  'CATS_DOGS/train/CAT/8847.jpg',
#  'CATS_DOGS/train/CAT/6479.jpg',
#  'CATS_DOGS/train/CAT/7211.jpg',
#  'CATS_DOGS/train/CAT/6064.jpg',
#  'CATS_DOGS/train/CAT/7940.jpg',
#  'CATS_DOGS/train/CAT/7186.jpg',
#  'CATS_DOGS/train/CAT/7754.jpg',
#  'CATS_DOGS/train/CAT/3709.jpg',
#  'CATS_DOGS/train/CAT/1559.jpg',
#  'CATS_DOGS/train/CAT/8283.jpg',
#  'CATS_DOGS/train/CAT/1605.jpg',
#  'CATS_DOGS/train/CAT/6558.jpg',
#  'CATS_DOGS/train/CAT/8457.jpg',
#  'CATS_DOGS/train/CAT/6639.jpg',
#  'CATS_DOGS/train/CAT/8401.jpg',
#  'CATS_DOGS/train/CAT/498.jpg',
#  'CATS_DOGS/train/CAT/7257.jpg',
#  'CATS_DOGS/train/CAT/8718.jpg',
#  'CATS_DOGS/train/CAT/9019.jpg',
#  'CATS_DOGS/train/CAT/5425.jpg',
#  'CATS_DOGS/train/CAT/7970.jpg',
#  'CATS_DOGS/train/CAT/5611.jpg',
#  'CATS_DOGS/train/CAT/1717.jpg',
#  'CATS_DOGS/train/CAT/801.jpg',
#  'CATS_DOGS/train/CAT/6843.jpg',
#  'CATS_DOGS/train/CAT/6457.jpg',
#  'CATS_DOGS/train/CAT/5857.jpg',
#  'CATS_DOGS/train/CAT/5463.jpg',
#  'CATS_DOGS/train/CAT/7470.jpg',
#  'CATS_DOGS/train/CAT/3376.jpg',
#  'CATS_DOGS/train/CAT/436.jpg',
#  'CATS_DOGS/train/CAT/9204.jpg',
#  'CATS_DOGS/train/CAT/6121.jpg',
#  'CATS_DOGS/train/CAT/6877.jpg',
#  'CATS_DOGS/train/CAT/5160.jpg',
#  'CATS_DOGS/train/CAT/6364.jpg',
#  'CATS_DOGS/train/CAT/158.jpg',
#  'CATS_DOGS/train/CAT/3527.jpg',
#  'CATS_DOGS/train/CAT/2660.jpg',
#  'CATS_DOGS/train/CAT/3692.jpg',
#  'CATS_DOGS/train/CAT/3217.jpg',
#  'CATS_DOGS/train/CAT/632.jpg',
#  'CATS_DOGS/train/CAT/293.jpg',
#  'CATS_DOGS/train/CAT/3391.jpg',
#  'CATS_DOGS/train/CAT/4513.jpg',
#  'CATS_DOGS/train/CAT/7042.jpg',
#  'CATS_DOGS/train/CAT/4333.jpg',
#  'CATS_DOGS/train/CAT/2095.jpg',
#  'CATS_DOGS/train/CAT/8950.jpg',
#  'CATS_DOGS/train/CAT/2843.jpg',
#  'CATS_DOGS/train/CAT/4644.jpg',
#  'CATS_DOGS/train/CAT/5406.jpg',
#  'CATS_DOGS/train/CAT/8015.jpg',
#  'CATS_DOGS/train/CAT/6522.jpg',
#  'CATS_DOGS/train/CAT/6257.jpg',
#  'CATS_DOGS/train/CAT/934.jpg',
#  'CATS_DOGS/train/CAT/6419.jpg',
#  'CATS_DOGS/train/CAT/5814.jpg',
#  'CATS_DOGS/train/CAT/1464.jpg',
#  'CATS_DOGS/train/CAT/1982.jpg',
#  'CATS_DOGS/train/CAT/6454.jpg',
#  'CATS_DOGS/train/CAT/2568.jpg',
#  'CATS_DOGS/train/CAT/906.jpg',
#  'CATS_DOGS/train/CAT/4880.jpg',
#  'CATS_DOGS/train/CAT/9285.jpg',
#  'CATS_DOGS/train/CAT/4044.jpg',
#  'CATS_DOGS/train/CAT/3696.jpg',
#  'CATS_DOGS/train/CAT/4246.jpg',
#  'CATS_DOGS/train/CAT/5612.jpg',
#  'CATS_DOGS/train/CAT/6195.jpg',
#  'CATS_DOGS/train/CAT/3536.jpg',
#  'CATS_DOGS/train/CAT/3439.jpg',
#  'CATS_DOGS/train/CAT/4366.jpg',
#  'CATS_DOGS/train/CAT/2958.jpg',
#  'CATS_DOGS/train/CAT/6670.jpg',
#  'CATS_DOGS/train/CAT/3499.jpg',
#  'CATS_DOGS/train/CAT/3480.jpg',
#  'CATS_DOGS/train/CAT/9155.jpg',
#  'CATS_DOGS/train/CAT/449.jpg',
#  'CATS_DOGS/train/CAT/4661.jpg',
#  'CATS_DOGS/train/CAT/5739.jpg',
#  'CATS_DOGS/train/CAT/2579.jpg',
#  'CATS_DOGS/train/CAT/6905.jpg',
#  'CATS_DOGS/train/CAT/8479.jpg',
#  'CATS_DOGS/train/CAT/7771.jpg',
#  'CATS_DOGS/train/CAT/8496.jpg',
#  'CATS_DOGS/train/CAT/5056.jpg',
#  'CATS_DOGS/train/CAT/1838.jpg',
#  'CATS_DOGS/train/CAT/5989.jpg',
#  'CATS_DOGS/train/CAT/8811.jpg',
#  'CATS_DOGS/train/CAT/6227.jpg',
#  'CATS_DOGS/train/CAT/1668.jpg',
#  'CATS_DOGS/train/CAT/1686.jpg',
#  'CATS_DOGS/train/CAT/197.jpg',
#  'CATS_DOGS/train/CAT/8244.jpg',
#  'CATS_DOGS/train/CAT/5578.jpg',
#  'CATS_DOGS/train/CAT/8440.jpg',
#  'CATS_DOGS/train/CAT/8816.jpg',
#  'CATS_DOGS/train/CAT/4997.jpg',
#  'CATS_DOGS/train/CAT/8419.jpg',
#  'CATS_DOGS/train/CAT/1649.jpg',
#  'CATS_DOGS/train/CAT/212.jpg',
#  'CATS_DOGS/train/CAT/5892.jpg',
#  'CATS_DOGS/train/CAT/2258.jpg',
#  'CATS_DOGS/train/CAT/332.jpg',
#  'CATS_DOGS/train/CAT/4785.jpg',
#  'CATS_DOGS/train/CAT/6208.jpg',
#  'CATS_DOGS/train/CAT/5535.jpg',
#  'CATS_DOGS/train/CAT/8551.jpg',
#  'CATS_DOGS/train/CAT/8647.jpg',
#  'CATS_DOGS/train/CAT/2709.jpg',
#  'CATS_DOGS/train/CAT/7831.jpg',
#  'CATS_DOGS/train/CAT/7204.jpg',
#  'CATS_DOGS/train/CAT/3531.jpg',
#  'CATS_DOGS/train/CAT/7989.jpg',
#  'CATS_DOGS/train/CAT/4000.jpg',
#  'CATS_DOGS/train/CAT/8124.jpg',
#  'CATS_DOGS/train/CAT/1887.jpg',
#  'CATS_DOGS/train/CAT/96.jpg',
#  'CATS_DOGS/train/CAT/3420.jpg',
#  'CATS_DOGS/train/CAT/7871.jpg',
#  'CATS_DOGS/train/CAT/5832.jpg',
#  'CATS_DOGS/train/CAT/7432.jpg',
#  'CATS_DOGS/train/CAT/6372.jpg',
#  'CATS_DOGS/train/CAT/7171.jpg',
#  'CATS_DOGS/train/CAT/6279.jpg',
#  'CATS_DOGS/train/CAT/8023.jpg',
#  'CATS_DOGS/train/CAT/2712.jpg',
#  'CATS_DOGS/train/CAT/2057.jpg',
#  'CATS_DOGS/train/CAT/3341.jpg',
#  'CATS_DOGS/train/CAT/172.jpg',
#  'CATS_DOGS/train/CAT/206.jpg',
#  'CATS_DOGS/train/CAT/2577.jpg',
#  'CATS_DOGS/train/CAT/4024.jpg',
#  'CATS_DOGS/train/CAT/6705.jpg',
#  'CATS_DOGS/train/CAT/5030.jpg',
#  'CATS_DOGS/train/CAT/894.jpg',
#  'CATS_DOGS/train/CAT/8670.jpg',
#  'CATS_DOGS/train/CAT/692.jpg',
#  'CATS_DOGS/train/CAT/9275.jpg',
#  'CATS_DOGS/train/CAT/2001.jpg',
#  'CATS_DOGS/train/CAT/1514.jpg',
#  'CATS_DOGS/train/CAT/1072.jpg',
#  'CATS_DOGS/train/CAT/1291.jpg',
#  'CATS_DOGS/train/CAT/6709.jpg',
#  'CATS_DOGS/train/CAT/9327.jpg',
#  'CATS_DOGS/train/CAT/8.jpg',
#  'CATS_DOGS/train/CAT/6740.jpg',
#  'CATS_DOGS/train/CAT/1113.jpg',
#  'CATS_DOGS/train/CAT/1641.jpg',
#  'CATS_DOGS/train/CAT/709.jpg',
#  'CATS_DOGS/train/CAT/3528.jpg',
#  'CATS_DOGS/train/CAT/5347.jpg',
#  'CATS_DOGS/train/CAT/4737.jpg',
#  'CATS_DOGS/train/CAT/3207.jpg',
#  'CATS_DOGS/train/CAT/7869.jpg',
#  'CATS_DOGS/train/CAT/1922.jpg',
#  'CATS_DOGS/train/CAT/8957.jpg',
#  'CATS_DOGS/train/CAT/3395.jpg',
#  'CATS_DOGS/train/CAT/5962.jpg',
#  'CATS_DOGS/train/CAT/97.jpg',
#  'CATS_DOGS/train/CAT/6275.jpg',
#  'CATS_DOGS/train/CAT/6181.jpg',
#  'CATS_DOGS/train/CAT/5861.jpg',
#  'CATS_DOGS/train/CAT/6420.jpg',
#  'CATS_DOGS/train/CAT/6475.jpg',
#  'CATS_DOGS/train/CAT/8345.jpg',
#  'CATS_DOGS/train/CAT/6642.jpg',
#  'CATS_DOGS/train/CAT/4447.jpg',
#  'CATS_DOGS/train/CAT/4884.jpg',
#  'CATS_DOGS/train/CAT/557.jpg',
#  'CATS_DOGS/train/CAT/5554.jpg',
#  'CATS_DOGS/train/CAT/5106.jpg',
#  'CATS_DOGS/train/CAT/1609.jpg',
#  'CATS_DOGS/train/CAT/6040.jpg',
#  'CATS_DOGS/train/CAT/3174.jpg',
#  'CATS_DOGS/train/CAT/4906.jpg',
#  'CATS_DOGS/train/CAT/7655.jpg',
#  'CATS_DOGS/train/CAT/7012.jpg',
#  'CATS_DOGS/train/CAT/3397.jpg',
#  'CATS_DOGS/train/CAT/3204.jpg',
#  'CATS_DOGS/train/CAT/4029.jpg',
#  'CATS_DOGS/train/CAT/6230.jpg',
#  'CATS_DOGS/train/CAT/1270.jpg',
#  'CATS_DOGS/train/CAT/611.jpg',
#  'CATS_DOGS/train/CAT/202.jpg',
#  'CATS_DOGS/train/CAT/6042.jpg',
#  'CATS_DOGS/train/CAT/1567.jpg',
#  'CATS_DOGS/train/CAT/5473.jpg',
#  'CATS_DOGS/train/CAT/5007.jpg',
#  'CATS_DOGS/train/CAT/7051.jpg',
#  'CATS_DOGS/train/CAT/4516.jpg',
#  'CATS_DOGS/train/CAT/1300.jpg',
#  'CATS_DOGS/train/CAT/6027.jpg',
#  'CATS_DOGS/train/CAT/6559.jpg',
#  'CATS_DOGS/train/CAT/4728.jpg',
#  'CATS_DOGS/train/CAT/2757.jpg',
#  'CATS_DOGS/train/CAT/6992.jpg',
#  'CATS_DOGS/train/CAT/1617.jpg',
#  'CATS_DOGS/train/CAT/7373.jpg',
#  'CATS_DOGS/train/CAT/6427.jpg',
#  'CATS_DOGS/train/CAT/5438.jpg',
#  'CATS_DOGS/train/CAT/7184.jpg',
#  'CATS_DOGS/train/CAT/389.jpg',
#  'CATS_DOGS/train/CAT/4416.jpg',
#  'CATS_DOGS/train/CAT/7381.jpg',
#  'CATS_DOGS/train/CAT/6648.jpg',
#  'CATS_DOGS/train/CAT/4399.jpg',
#  'CATS_DOGS/train/CAT/1225.jpg',
#  'CATS_DOGS/train/CAT/4720.jpg',
#  'CATS_DOGS/train/CAT/6118.jpg',
#  'CATS_DOGS/train/CAT/9269.jpg',
#  'CATS_DOGS/train/CAT/2327.jpg',
#  'CATS_DOGS/train/CAT/9057.jpg',
#  'CATS_DOGS/train/CAT/6356.jpg',
#  'CATS_DOGS/train/CAT/5580.jpg',
#  'CATS_DOGS/train/CAT/5432.jpg',
#  'CATS_DOGS/train/CAT/4986.jpg',
#  'CATS_DOGS/train/CAT/1164.jpg',
#  'CATS_DOGS/train/CAT/8969.jpg',
#  'CATS_DOGS/train/CAT/5750.jpg',
#  'CATS_DOGS/train/CAT/9117.jpg',
#  'CATS_DOGS/train/CAT/244.jpg',
#  'CATS_DOGS/train/CAT/2398.jpg',
#  'CATS_DOGS/train/CAT/3329.jpg',
#  'CATS_DOGS/train/CAT/7156.jpg',
#  'CATS_DOGS/train/CAT/1817.jpg',
#  'CATS_DOGS/train/CAT/4836.jpg',
#  'CATS_DOGS/train/CAT/1026.jpg',
#  'CATS_DOGS/train/CAT/8771.jpg',
#  'CATS_DOGS/train/CAT/4433.jpg',
#  'CATS_DOGS/train/CAT/5995.jpg',
#  'CATS_DOGS/train/CAT/2025.jpg',
#  'CATS_DOGS/train/CAT/9174.jpg',
#  'CATS_DOGS/train/CAT/6328.jpg',
#  'CATS_DOGS/train/CAT/2804.jpg',
#  'CATS_DOGS/train/CAT/984.jpg',
#  'CATS_DOGS/train/CAT/6664.jpg',
#  'CATS_DOGS/train/CAT/8063.jpg',
#  'CATS_DOGS/train/CAT/2857.jpg',
#  'CATS_DOGS/train/CAT/2790.jpg',
#  'CATS_DOGS/train/CAT/1722.jpg',
#  'CATS_DOGS/train/CAT/1861.jpg',
#  'CATS_DOGS/train/CAT/4751.jpg',
#  'CATS_DOGS/train/CAT/2789.jpg',
#  'CATS_DOGS/train/CAT/2288.jpg',
#  'CATS_DOGS/train/CAT/674.jpg',
#  'CATS_DOGS/train/CAT/5457.jpg',
#  'CATS_DOGS/train/CAT/2729.jpg',
#  'CATS_DOGS/train/CAT/3698.jpg',
#  'CATS_DOGS/train/CAT/4317.jpg',
#  'CATS_DOGS/train/CAT/7426.jpg',
#  'CATS_DOGS/train/CAT/8764.jpg',
#  'CATS_DOGS/train/CAT/4685.jpg',
#  'CATS_DOGS/train/CAT/2650.jpg',
#  'CATS_DOGS/train/CAT/7402.jpg',
#  'CATS_DOGS/train/CAT/3891.jpg',
#  'CATS_DOGS/train/CAT/1704.jpg',
#  'CATS_DOGS/train/CAT/2405.jpg',
#  'CATS_DOGS/train/CAT/6138.jpg',
#  'CATS_DOGS/train/CAT/7677.jpg',
#  'CATS_DOGS/train/CAT/5376.jpg',
#  'CATS_DOGS/train/CAT/3001.jpg',
#  'CATS_DOGS/train/CAT/4012.jpg',
#  'CATS_DOGS/train/CAT/4985.jpg',
#  'CATS_DOGS/train/CAT/9366.jpg',
#  'CATS_DOGS/train/CAT/7442.jpg',
#  'CATS_DOGS/train/CAT/3851.jpg',
#  'CATS_DOGS/train/CAT/6033.jpg',
#  'CATS_DOGS/train/CAT/6484.jpg',
#  'CATS_DOGS/train/CAT/6247.jpg',
#  'CATS_DOGS/train/CAT/3345.jpg',
#  'CATS_DOGS/train/CAT/1596.jpg',
#  'CATS_DOGS/train/CAT/5576.jpg',
#  'CATS_DOGS/train/CAT/764.jpg',
#  'CATS_DOGS/train/CAT/5243.jpg',
#  'CATS_DOGS/train/CAT/6568.jpg',
#  'CATS_DOGS/train/CAT/1231.jpg',
#  'CATS_DOGS/train/CAT/497.jpg',
#  'CATS_DOGS/train/CAT/6531.jpg',
#  'CATS_DOGS/train/CAT/2021.jpg',
#  'CATS_DOGS/train/CAT/6716.jpg',
#  'CATS_DOGS/train/CAT/3361.jpg',
#  'CATS_DOGS/train/CAT/5682.jpg',
#  'CATS_DOGS/train/CAT/6458.jpg',
#  'CATS_DOGS/train/CAT/3541.jpg',
#  'CATS_DOGS/train/CAT/5251.jpg',
#  'CATS_DOGS/train/CAT/2981.jpg',
#  'CATS_DOGS/train/CAT/7730.jpg',
#  'CATS_DOGS/train/CAT/4305.jpg',
#  'CATS_DOGS/train/CAT/7731.jpg',
#  'CATS_DOGS/train/CAT/5782.jpg',
#  'CATS_DOGS/train/CAT/4698.jpg',
#  'CATS_DOGS/train/CAT/7679.jpg',
#  'CATS_DOGS/train/CAT/7474.jpg',
#  'CATS_DOGS/train/CAT/8871.jpg',
#  'CATS_DOGS/train/CAT/7081.jpg',
#  'CATS_DOGS/train/CAT/4522.jpg',
#  'CATS_DOGS/train/CAT/3559.jpg',
#  'CATS_DOGS/train/CAT/5900.jpg',
#  'CATS_DOGS/train/CAT/3685.jpg',
#  'CATS_DOGS/train/CAT/2315.jpg',
#  'CATS_DOGS/train/CAT/3112.jpg',
#  'CATS_DOGS/train/CAT/1.jpg',
#  'CATS_DOGS/train/CAT/5517.jpg',
#  'CATS_DOGS/train/CAT/2344.jpg',
#  'CATS_DOGS/train/CAT/5426.jpg',
#  'CATS_DOGS/train/CAT/5313.jpg',
#  'CATS_DOGS/train/CAT/307.jpg',
#  'CATS_DOGS/train/CAT/3975.jpg',
#  'CATS_DOGS/train/CAT/9140.jpg',
#  'CATS_DOGS/train/CAT/5519.jpg',
#  'CATS_DOGS/train/CAT/7698.jpg',
#  'CATS_DOGS/train/CAT/8804.jpg',
#  'CATS_DOGS/train/CAT/8005.jpg',
#  'CATS_DOGS/train/CAT/3424.jpg',
#  'CATS_DOGS/train/CAT/1904.jpg',
#  'CATS_DOGS/train/CAT/723.jpg',
#  'CATS_DOGS/train/CAT/7063.jpg',
#  'CATS_DOGS/train/CAT/8060.jpg',
#  'CATS_DOGS/train/CAT/2304.jpg',
#  'CATS_DOGS/train/CAT/1791.jpg',
#  'CATS_DOGS/train/CAT/7439.jpg',
#  'CATS_DOGS/train/CAT/2354.jpg',
#  'CATS_DOGS/train/CAT/3760.jpg',
#  'CATS_DOGS/train/CAT/4364.jpg',
#  'CATS_DOGS/train/CAT/8184.jpg',
#  'CATS_DOGS/train/CAT/3153.jpg',
#  'CATS_DOGS/train/CAT/3492.jpg',
#  'CATS_DOGS/train/CAT/7179.jpg',
#  'CATS_DOGS/train/CAT/5864.jpg',
#  'CATS_DOGS/train/CAT/881.jpg',
#  'CATS_DOGS/train/CAT/227.jpg',
#  'CATS_DOGS/train/CAT/6938.jpg',
#  'CATS_DOGS/train/CAT/4694.jpg',
#  'CATS_DOGS/train/CAT/2687.jpg',
#  'CATS_DOGS/train/CAT/2765.jpg',
#  'CATS_DOGS/train/CAT/1697.jpg',
#  'CATS_DOGS/train/CAT/4584.jpg',
#  'CATS_DOGS/train/CAT/1913.jpg',
#  'CATS_DOGS/train/CAT/1951.jpg',
#  'CATS_DOGS/train/CAT/7977.jpg',
#  'CATS_DOGS/train/CAT/7685.jpg',
#  'CATS_DOGS/train/CAT/132.jpg',
#  'CATS_DOGS/train/CAT/3504.jpg',
#  'CATS_DOGS/train/CAT/6543.jpg',
#  'CATS_DOGS/train/CAT/5326.jpg',
#  'CATS_DOGS/train/CAT/4392.jpg',
#  'CATS_DOGS/train/CAT/4221.jpg',
#  'CATS_DOGS/train/CAT/3778.jpg',
#  'CATS_DOGS/train/CAT/1844.jpg',
#  'CATS_DOGS/train/CAT/8754.jpg',
#  'CATS_DOGS/train/CAT/3730.jpg',
#  'CATS_DOGS/train/CAT/2530.jpg',
#  'CATS_DOGS/train/CAT/3473.jpg',
#  'CATS_DOGS/train/CAT/124.jpg',
#  'CATS_DOGS/train/CAT/7121.jpg',
#  'CATS_DOGS/train/CAT/504.jpg',
#  'CATS_DOGS/train/CAT/379.jpg',
#  'CATS_DOGS/train/CAT/2900.jpg',
#  'CATS_DOGS/train/CAT/6517.jpg',
#  'CATS_DOGS/train/CAT/2490.jpg',
#  'CATS_DOGS/train/CAT/6802.jpg',
#  'CATS_DOGS/train/CAT/9313.jpg',
#  'CATS_DOGS/train/CAT/6218.jpg',
#  'CATS_DOGS/train/CAT/7346.jpg',
#  'CATS_DOGS/train/CAT/2618.jpg',
#  'CATS_DOGS/train/CAT/5100.jpg',
#  'CATS_DOGS/train/CAT/4855.jpg',
#  'CATS_DOGS/train/CAT/2218.jpg',
#  'CATS_DOGS/train/CAT/5629.jpg',
#  'CATS_DOGS/train/CAT/2894.jpg',
#  'CATS_DOGS/train/CAT/5070.jpg',
#  'CATS_DOGS/train/CAT/6678.jpg',
#  'CATS_DOGS/train/CAT/3349.jpg',
#  'CATS_DOGS/train/CAT/4546.jpg',
#  'CATS_DOGS/train/CAT/8289.jpg',
#  'CATS_DOGS/train/CAT/6081.jpg',
#  'CATS_DOGS/train/CAT/2054.jpg',
#  'CATS_DOGS/train/CAT/506.jpg',
#  'CATS_DOGS/train/CAT/1483.jpg',
#  'CATS_DOGS/train/CAT/2844.jpg',
#  'CATS_DOGS/train/CAT/9371.jpg',
#  'CATS_DOGS/train/CAT/701.jpg',
#  'CATS_DOGS/train/CAT/5400.jpg',
#  'CATS_DOGS/train/CAT/5342.jpg',
#  'CATS_DOGS/train/CAT/6661.jpg',
#  'CATS_DOGS/train/CAT/7070.jpg',
#  'CATS_DOGS/train/CAT/2002.jpg',
#  'CATS_DOGS/train/CAT/6894.jpg',
#  'CATS_DOGS/train/CAT/6861.jpg',
#  'CATS_DOGS/train/CAT/376.jpg',
#  'CATS_DOGS/train/CAT/1429.jpg',
#  'CATS_DOGS/train/CAT/162.jpg',
#  'CATS_DOGS/train/CAT/2492.jpg',
#  'CATS_DOGS/train/CAT/6547.jpg',
#  'CATS_DOGS/train/CAT/5274.jpg',
#  'CATS_DOGS/train/CAT/4711.jpg',
#  'CATS_DOGS/train/CAT/1991.jpg',
#  'CATS_DOGS/train/CAT/8396.jpg',
#  'CATS_DOGS/train/CAT/4272.jpg',
#  'CATS_DOGS/train/CAT/3190.jpg',
#  'CATS_DOGS/train/CAT/2265.jpg',
#  'CATS_DOGS/train/CAT/8658.jpg',
#  'CATS_DOGS/train/CAT/8517.jpg',
#  'CATS_DOGS/train/CAT/2284.jpg',
#  'CATS_DOGS/train/CAT/1383.jpg',
#  'CATS_DOGS/train/CAT/3013.jpg',
#  'CATS_DOGS/train/CAT/1285.jpg',
#  'CATS_DOGS/train/CAT/1486.jpg',
#  'CATS_DOGS/train/CAT/7196.jpg',
#  'CATS_DOGS/train/CAT/999.jpg',
#  'CATS_DOGS/train/CAT/838.jpg',
#  'CATS_DOGS/train/CAT/805.jpg',
#  'CATS_DOGS/train/CAT/3705.jpg',
#  'CATS_DOGS/train/CAT/7319.jpg',
#  'CATS_DOGS/train/CAT/5776.jpg',
#  'CATS_DOGS/train/CAT/2938.jpg',
#  'CATS_DOGS/train/CAT/3232.jpg',
#  'CATS_DOGS/train/CAT/5316.jpg',
#  'CATS_DOGS/train/CAT/3895.jpg',
#  'CATS_DOGS/train/CAT/6401.jpg',
#  'CATS_DOGS/train/CAT/5125.jpg',
#  'CATS_DOGS/train/CAT/4457.jpg',
#  'CATS_DOGS/train/CAT/8470.jpg',
#  'CATS_DOGS/train/CAT/2886.jpg',
#  'CATS_DOGS/train/CAT/956.jpg',
#  'CATS_DOGS/train/CAT/2941.jpg',
#  'CATS_DOGS/train/CAT/7214.jpg',
#  'CATS_DOGS/train/CAT/9128.jpg',
#  'CATS_DOGS/train/CAT/3723.jpg',
#  'CATS_DOGS/train/CAT/4031.jpg',
#  'CATS_DOGS/train/CAT/8066.jpg',
#  'CATS_DOGS/train/CAT/9066.jpg',
#  'CATS_DOGS/train/CAT/3087.jpg',
#  'CATS_DOGS/train/CAT/2309.jpg',
#  'CATS_DOGS/train/CAT/8339.jpg',
#  'CATS_DOGS/train/CAT/8483.jpg',
#  'CATS_DOGS/train/CAT/1212.jpg',
#  'CATS_DOGS/train/CAT/7124.jpg',
#  'CATS_DOGS/train/CAT/3837.jpg',
#  'CATS_DOGS/train/CAT/1134.jpg',
#  'CATS_DOGS/train/CAT/6720.jpg',
#  'CATS_DOGS/train/CAT/7872.jpg',
#  'CATS_DOGS/train/CAT/4334.jpg',
#  'CATS_DOGS/train/CAT/4359.jpg',
#  'CATS_DOGS/train/CAT/8902.jpg',
#  'CATS_DOGS/train/CAT/57.jpg',
#  'CATS_DOGS/train/CAT/8985.jpg',
#  'CATS_DOGS/train/CAT/9343.jpg',
#  'CATS_DOGS/train/CAT/4943.jpg',
#  'CATS_DOGS/train/CAT/5501.jpg',
#  'CATS_DOGS/train/CAT/1069.jpg',
#  'CATS_DOGS/train/CAT/3532.jpg',
#  'CATS_DOGS/train/CAT/8738.jpg',
#  'CATS_DOGS/train/CAT/4673.jpg',
#  'CATS_DOGS/train/CAT/7079.jpg',
#  'CATS_DOGS/train/CAT/8145.jpg',
#  'CATS_DOGS/train/CAT/5260.jpg',
#  'CATS_DOGS/train/CAT/5686.jpg',
#  'CATS_DOGS/train/CAT/7911.jpg',
#  'CATS_DOGS/train/CAT/1570.jpg',
#  'CATS_DOGS/train/CAT/4547.jpg',
#  'CATS_DOGS/train/CAT/5332.jpg',
#  'CATS_DOGS/train/CAT/2345.jpg',
#  'CATS_DOGS/train/CAT/3872.jpg',
#  'CATS_DOGS/train/CAT/5846.jpg',
#  'CATS_DOGS/train/CAT/1746.jpg',
#  'CATS_DOGS/train/CAT/3759.jpg',
#  'CATS_DOGS/train/CAT/4712.jpg',
#  'CATS_DOGS/train/CAT/895.jpg',
#  'CATS_DOGS/train/CAT/6616.jpg',
#  'CATS_DOGS/train/CAT/2685.jpg',
#  'CATS_DOGS/train/CAT/6240.jpg',
#  'CATS_DOGS/train/CAT/7795.jpg',
#  'CATS_DOGS/train/CAT/4792.jpg',
#  'CATS_DOGS/train/CAT/2053.jpg',
#  'CATS_DOGS/train/CAT/2602.jpg',
#  'CATS_DOGS/train/CAT/8974.jpg',
#  'CATS_DOGS/train/CAT/3737.jpg',
#  'CATS_DOGS/train/CAT/3946.jpg',
#  'CATS_DOGS/train/CAT/3677.jpg',
#  'CATS_DOGS/train/CAT/338.jpg',
#  'CATS_DOGS/train/CAT/3417.jpg',
#  'CATS_DOGS/train/CAT/1335.jpg',
#  'CATS_DOGS/train/CAT/1828.jpg',
#  'CATS_DOGS/train/CAT/5657.jpg',
#  'CATS_DOGS/train/CAT/7516.jpg',
#  'CATS_DOGS/train/CAT/7475.jpg',
#  'CATS_DOGS/train/CAT/4256.jpg',
#  'CATS_DOGS/train/CAT/7614.jpg',
#  'CATS_DOGS/train/CAT/3697.jpg',
#  'CATS_DOGS/train/CAT/1853.jpg',
#  'CATS_DOGS/train/CAT/3344.jpg',
#  'CATS_DOGS/train/CAT/3140.jpg',
#  'CATS_DOGS/train/CAT/3300.jpg',
#  'CATS_DOGS/train/CAT/5610.jpg',
#  'CATS_DOGS/train/CAT/6.jpg',
#  'CATS_DOGS/train/CAT/5843.jpg',
#  'CATS_DOGS/train/CAT/936.jpg',
#  'CATS_DOGS/train/CAT/3818.jpg',
#  'CATS_DOGS/train/CAT/8121.jpg',
#  'CATS_DOGS/train/CAT/7472.jpg',
#  'CATS_DOGS/train/CAT/5728.jpg',
#  'CATS_DOGS/train/CAT/3749.jpg',
#  'CATS_DOGS/train/CAT/6823.jpg',
#  'CATS_DOGS/train/CAT/5448.jpg',
#  'CATS_DOGS/train/CAT/5808.jpg',
#  'CATS_DOGS/train/CAT/1112.jpg',
#  'CATS_DOGS/train/CAT/9241.jpg',
#  'CATS_DOGS/train/CAT/1878.jpg',
#  'CATS_DOGS/train/CAT/7539.jpg',
#  'CATS_DOGS/train/CAT/8900.jpg',
#  'CATS_DOGS/train/CAT/721.jpg',
#  'CATS_DOGS/train/CAT/6929.jpg',
#  'CATS_DOGS/train/CAT/4945.jpg',
#  'CATS_DOGS/train/CAT/8048.jpg',
#  'CATS_DOGS/train/CAT/2321.jpg',
#  'CATS_DOGS/train/CAT/4461.jpg',
#  'CATS_DOGS/train/CAT/9317.jpg',
#  'CATS_DOGS/train/CAT/2816.jpg',
#  'CATS_DOGS/train/CAT/2539.jpg',
#  'CATS_DOGS/train/CAT/4276.jpg',
#  'CATS_DOGS/train/CAT/4670.jpg',
#  'CATS_DOGS/train/CAT/8198.jpg',
#  'CATS_DOGS/train/CAT/2532.jpg',
#  'CATS_DOGS/train/CAT/1815.jpg',
#  'CATS_DOGS/train/CAT/5042.jpg',
#  'CATS_DOGS/train/CAT/1155.jpg',
#  'CATS_DOGS/train/CAT/7450.jpg',
#  'CATS_DOGS/train/CAT/8355.jpg',
#  'CATS_DOGS/train/CAT/3119.jpg',
#  ...]

# %% [markdown]
# ### Create a DataFrame of image sizes (width x height)
# It's worth noting that <tt>Image.open()</tt> doesn't read the entire image into memory, so it's a reasonable way to get image sizes.<br>
# Still, this can take awhile.

# %%
# Start by creating a list
img_sizes = []
rejected = []

for item in img_names:
    try:
        with Image.open(item) as img:
            img_sizes.append(img.size)
    except:
        rejected.append(item)
        
print(f'Images:  {len(img_sizes)}')
print(f'Rejects: {len(rejected)}')
# Out:
# Images:  24994
# Rejects: 0

# %%
# Convert the list to a DataFrame
df = pd.DataFrame(img_sizes)

# Run summary statistics on image widths
df[0].describe()
# Out:
# count    24994.000000
# mean       404.493518
# std        108.941802
# min         42.000000
# 25%        323.000000
# 50%        448.000000
# 75%        500.000000
# max        500.000000
# Name: 0, dtype: float64

# %%
# Run summary statistics on image heights
df[1].describe()
# Out:
# count    24994.000000
# mean       361.037129
# std         96.936811
# min         33.000000
# 25%        302.000000
# 50%        375.000000
# 75%        421.000000
# max        500.000000
# Name: 1, dtype: float64

# %% [markdown]
# This tells us the shortest width is 42, the shortest height is 33, the largest width and height are 500, and that most images have more than 300 pixels per side. This is useful for deciding on an input size. We'll see in the next section that 224x224 will work well for our purposes (we'll take advantage of some pre-trained models that use this size!)

# %% [markdown]
# ## Image Preprocessing
# Any network we define requires consistent input data. That is, the incoming image files need to have the same number of channels (3 for red/green/blue), the same depth per channel (0-255), and the same height and width. This last requirement can be tricky. How do we transform an 800x450 pixel image into one that is 224x224? In the theory lectures we covered the following:
# * <a href='https://en.wikipedia.org/wiki/Aspect_ratio_(image)'><strong>aspect ratio</strong></a>: the ratio of width to height (16:9, 1:1, etc.) An 800x450 pixel image has an aspect ration of 16:9. We can change the aspect ratio of an image by cropping it, by stretching/squeezing it, or by some combination of the two. In both cases we lose some information contained in the original. Let's say we crop 175 pixels from the left and right sides of our 800x450 image, resulting in one that's 450x450.
# * <strong>scale</strong>: Once we've attained the proper aspect ratio we may need to scale an image up or down to fit our input parameters. There are several libraries we can use to scale a 450x450 image down to 224x224 with minimal loss.
# * <a href=''><strong>normalization</strong></a>: when images are converted to tensors, the [0,255] rgb channels are loaded into range [0,1]. We can then normalize them using the generally accepted values of mean=[0.485, 0.456, 0.406] and std=[0.229, 0.224, 0.225]. For the curious, these values were obtained by the PyTorch team using a random 10,000 sample of <a href='http://www.image-net.org/'>ImageNet</a> images. There's a good discussion of this <a href='https://discuss.pytorch.org/t/normalization-in-the-mnist-example/457/22'>here</a>, and the original source code can be found <a href='https://github.com/soumith/imagenet-multiGPU.torch/blob/master/donkey.lua#L154'>here</a>.

# %% [markdown]
# ## Transformations
# Before defining our Convolutional Network, let's look at a sample image and perform various transformations on it to see their effect.

# %%
dog = Image.open('CATS_DOGS/train/DOG/14.jpg')
print(dog.size)
display(dog)
# Out:
# (500, 387)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x387 at 0x7F2B68E19490>

# %% [markdown]
# This is how jupyter displays the original .jpg image. Note that size is given as (width, height).<br>
# Let's look at a single pixel:

# %%
r, g, b = dog.getpixel((0, 0))
print(r,g,b)
# Out:
# 90 95 98

# %% [markdown]
# The pixel at position [0,0] (upper left) of the source image has an rgb value of (90,95,98). This corresponds to <font style="background-color:rgb(90,95,98)">this color </font><br>
# Great! Now let's look at some specific transformations.
# ### <a href='https://pytorch.org/docs/stable/torchvision/transforms.html#torchvision.transforms.ToTensor'><tt>transforms.ToTensor()</tt></a>
# Converts a PIL Image or numpy.ndarray (HxWxC) in the range [0, 255] to a <tt>torch.FloatTensor</tt> of shape (CxHxW) in the range [0.0, 1.0]

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
# Out:
# torch.Size([3, 387, 500])

# %%
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));

# %% [markdown]
# This is the same image converted to a tensor and displayed using matplotlib. Note that the torch dimensions follow [channel, height, width]<br><br>
# PyTorch automatically loads the [0,255] pixel channels to [0,1]:<br><br>
# $\frac{90}{255}=0.3529\quad\frac{95}{255}=0.3725\quad\frac{98}{255}=0.3843$

# %%
im[:,0,0]
# Out:
# tensor([0.3529, 0.3725, 0.3843])

# %% [markdown]
# ### <a href='https://pytorch.org/docs/stable/torchvision/transforms.html#torchvision.transforms.Resize'><tt>transforms.Resize(<em>size</em>)</tt></a>
# If size is a sequence like (h, w), the output size will be matched to this. If size is an integer, the smaller edge of the image will be matched to this number.<br>i.e, if height > width, then the image will be rescaled to (size * height / width, size)

# %%
transform = transforms.Compose([
    transforms.Resize(224), 
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));

# %% [markdown]
# This resized the shortest side, and scaled the other. Let's try this on a small image.

# %%
small_dog = Image.open('CATS_DOGS/train/DOG/11.jpg')
print(small_dog.size)
display(small_dog)

# %%
im = transform(small_dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));

# %% [markdown]
# ### <a href='https://pytorch.org/docs/stable/torchvision/transforms.html#torchvision.transforms.CenterCrop'><tt>transforms.CenterCrop(<em>size</em>)</tt></a>
# If size is an integer instead of sequence like (h, w), a square crop of (size, size) is made.

# %%
transform = transforms.Compose([
    transforms.CenterCrop(224), 
    transforms.ToTensor()
])
im = transform(dog) # this crops the original image
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));

# %% [markdown]
# It may be better to resize the image first, then crop:

# %%
transform = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224), 
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));

# %% [markdown]
# ## Other affine transformations
# An <a href='https://en.wikipedia.org/wiki/Affine_transformation'><em>affine</em></a> transformation is one that preserves points and straight lines. Examples include rotation, reflection, and scaling. For instance, we can double the effective size of our training set simply by flipping the images.
# ### <a href='https://pytorch.org/docs/stable/torchvision/transforms.html#torchvision.transforms.RandomHorizontalFlip'><tt>transforms.RandomHorizontalFlip(<em>p=0.5</em>)</tt></a>
# Horizontally flip the given PIL image randomly with a given probability.

# %%
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),  # normally we'd set p=0.5
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));

# %% [markdown]
# ### <a href='https://pytorch.org/docs/stable/torchvision/transforms.html#torchvision.transforms.RandomRotation'><tt>transforms.RandomRotation(<em>degrees</em>)</tt></a>
# If degrees is a number instead of sequence like (min, max), the range of degrees will be (-degrees, +degrees).<br>
# Run the cell below several times to see a sample of rotations.

# %%
transform = transforms.Compose([
    transforms.RandomRotation(30),  # rotate randomly between +/- 30 degrees
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));

# %% [markdown]
# ### Scaling is done using <a href='https://pytorch.org/docs/stable/torchvision/transforms.html#torchvision.transforms.Resize'><tt>transforms.Resize(<em>size</em>)</tt></a>

# %%
transform = transforms.Compose([
    transforms.Resize((224,224)),  # be sure to pass in a list or a tuple
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));

# %% [markdown]
# ## Let's put it all together

# %%
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=1),  # normally we'd set p=0.5
    transforms.RandomRotation(30),
    transforms.Resize(224),
    transforms.CenterCrop(224), 
    transforms.ToTensor()
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));

# %% [markdown]
# ___
# ## Normalization
# Once the image has been loaded into a tensor, we can perform normalization on it. This serves to make convergence happen quicker during training. The values are somewhat arbitrary - you can use a mean of 0.5 and a standard deviation of 0.5 to convert a range of [0,1] to [-1,1], for example.<br>However, <a href='https://discuss.pytorch.org/t/normalization-in-the-mnist-example/457/22'>research has shown</a> that mean=[0.485, 0.456, 0.406] and std=[0.229, 0.224, 0.225] work well in practice.
#
# ### <a href='https://pytorch.org/docs/stable/torchvision/transforms.html#torchvision.transforms.Normalize'><tt>transforms.Normalize(<em>mean, std</em>)</tt></a>
# Given mean: (M1,...,Mn) and std: (S1,..,Sn) for n channels, this transform will normalize each channel of the input tensor
# ### $\quad\textrm {input[channel]} = \frac{\textrm{input[channel] - mean[channel]}}{\textrm {std[channel]}}$

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])
im = transform(dog)
print(im.shape)
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));

# %% [markdown]
# Recall that before normalization, the upper-leftmost tensor had pixel values of <tt>[0.3529, 0.3725, 0.3843]</tt>.<br>
# With normalization we subtract the channel mean from the input channel, then divide by the channel std.<br><br>
# $\frac{(0.3529-0.485)}{0.229}=-0.5767\quad\frac{(0.3725-0.456)}{0.224}=-0.3725\quad\frac{(0.3843-0.406)}{0.225}=-0.0964$<br>

# %%
# After normalization:
im[:,0,0]

# %% [markdown]
# When displayed, matplotlib clipped this particular pixel up to [0,0,0] so it appears black on the screen. However, the appearance isn't important; the goal of normalization is improved mathematical performance.

# %% [markdown]
# ### Optional: De-normalize the images
# To see the image back in its true colors, we can apply an inverse-transform to the tensor being displayed.

# %%
inv_normalize = transforms.Normalize(
    mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
    std=[1/0.229, 1/0.224, 1/0.225]
)
im_inv = inv_normalize(im)
plt.figure(figsize=(12,4))
plt.imshow(np.transpose(im_inv.numpy(), (1, 2, 0)));

# %% [markdown]
# Note that the original tensor was not modified:

# %%
plt.figure(figsize=(12,4))
plt.imshow(np.transpose(im.numpy(), (1, 2, 0)));
